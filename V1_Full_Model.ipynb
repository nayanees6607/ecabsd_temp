# %% [markdown]
# # ECABSD V1 (Full Model) Training on DB5
# This notebook trains the gold-standard ECABSD model using the DB5 dataset.
#
# **Instructions:**
# 1. Upload `ecabsd_db5.zip` to this Colab instance.
# 2. Run all cells.

# %%
# 1. Unzip the repository and install dependencies
# !unzip -q -o ecabsd_db5.zip
# !pip install -q torch_geometric
# !pip install -q -r requirements.txt

# %%
# 2. Run the training script (reads from config.yaml)
# !python train.py
