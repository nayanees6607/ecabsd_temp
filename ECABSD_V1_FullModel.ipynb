# %% [markdown]
# # ECABSD V1 (Full Model) - DB5 Retraining
# This is the complete, self-contained notebook to retrain the Baseline V1 Full Model on the DB5 Benchmark.

# %% [markdown]
# ### Step 1: Install Dependencies

# %%
# !pip install -q torch_geometric
# !pip install -q pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.0.0+cu118.html

# %% [markdown]
# ### Step 2: Clone Repo & Load Data

# %%
import os
import sys

# Clone your repo (replace with your actual git repo if you push to git)
# Or just assume the files are uploaded to the Colab environment.
if not os.path.exists('data/db5_processed'):
    print("Please upload ecabsd_db5.zip and unzip it first!")
    # !unzip -q -o ecabsd_db5.zip

# %% [markdown]
# ### Step 3: Run the Training Script
# Since your V1 architecture is already perfectly defined in `models/ecabsd_model.py` and the training loop is in `train.py`, the cleanest way to train the full model is just to run the script directly. This prevents copy-paste errors and ensures you use the exact same architecture for final publication.

# %%
# !python train.py

# %% [markdown]
# *(Note: If you specifically want all the Python code copy-pasted into these cells instead of running `train.py`, let me know! But running `train.py` directly is the safest way to ensure your published model exactly matches your GitHub repo).*
